# %% [markdown]
# # **Proyecto Final de IA2: Autoencoders para colorear imágenes**

# %% [markdown]
# ![bannerIA2.png](data:image/png;base64,...)

# %% [markdown]
# La coloración de imágenes mediante diferentes programas requiere una gran cantidad de esfuerzo humano, tiempo y habilidad, pero un tipo especial de arquitectura de deep learning llamada "autoencoder" ha facilitado mucho esta tarea. La coloración automática de imágenes suele implicar el uso de una clase de redes neuronales convolucionales (CNN) denominadas autoencoders, las cuales son capaces de extraer las características más destacadas de una imagen y, a continuación, regenerar la imagen basándose en estas características aprendidas.
#
# El objetivo principal de este proyecto es crear un autoencoder que pueda colorear imágenes de paisajes en escala de grises.

# %% [markdown]
# **Integrantes:**
# - David Felipe Rojas Casadiego. 2170136
# - Nicolas Galvan Alvarez. 2170104
# - Hazel David Pinzón Uribe. 2163022

# %% [markdown]
# # Coloreado de imagenes de Bucaramanga

# %% [markdown]
# ## Predicciones del modelo sin concatenar capas

# %%
def sorted_alphanumeric(data):  
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)',key)]
    return sorted(data,key = alphanum_key)
# defining the size of the image
SIZE = 160
color_img = []
path = '/content/drive/MyDrive/Proyecto-IA2/BucaramangaImagenes/Resized/160'
files = os.listdir(path)
files = sorted_alphanumeric(files)
for i in tqdm(files):    
    if i == '3000.jpg':
        break
    else:    
        img = cv2.imread(path + '/'+i,1)

        #resizing image
        img = cv2.resize(img, (SIZE, SIZE))
        img = img.astype('float32') / 255.0
        color_img.append(img_to_array(img))
# Out:
# 100%|██████████| 17/17 [00:00<00:00, 150.85it/s]

# %%
from keras.models import Model, load_model
autoencoder = load_model('/content/drive/MyDrive/Proyecto-IA2/Modelos/modelo-AE-concatL.h5')

# %%
def plot_images(color,predicted):
    plt.figure(figsize=(15,15))
    plt.subplot(1,3,1)
    plt.title('Imagen a color', color = 'green', fontsize = 20)
    plt.imshow(color)

    plt.subplot(1,3,3)
    plt.title('Imagen predicha ', color = 'Red', fontsize = 20)
    plt.imshow(predicted)
   
    plt.show()

mse_ncL, rmse_ncL, psnr_ncL, fsim_ncL, uqi_ncL, ssim_ncL, uiq_ncL, vif_ncL = [],[],[],[],[],[],[],[]
for i in range(0,17):
    predicted = np.clip(autoencoder.predict(color_img[i].reshape(1,SIZE, SIZE,3)),0.0,1.0).reshape(SIZE, SIZE,3)
    plot_images(color_img[i],predicted)

# %% [markdown]
# ## Predicciones del modelo sin concatenar y aumentando las capas

# %%
def sorted_alphanumeric(data):  
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)',key)]
    return sorted(data,key = alphanum_key)
# defining the size of the image
SIZE = 160
color_img = []
path = '/content/drive/MyDrive/Proyecto-IA2/BucaramangaImagenes/Resized/160'
files = os.listdir(path)
files = sorted_alphanumeric(files)
for i in tqdm(files):    
    if i == '3000.jpg':
        break
    else:    
        img = cv2.imread(path + '/'+i,1)

        #resizing image
        img = cv2.resize(img, (SIZE, SIZE))
        img = img.astype('float32') / 255.0
        color_img.append(img_to_array(img))
# Out:
# 100%|██████████| 17/17 [00:00<00:00, 131.73it/s]

# %%
from keras.models import Model, load_model
autoencoder = load_model('/content/drive/MyDrive/Proyecto-IA2/Modelos/modelo-AE-noconcatM.h5')

# %%
def plot_images(color,predicted):
    plt.figure(figsize=(15,15))
    plt.subplot(1,3,1)
    plt.title('Imagen a color', color = 'green', fontsize = 20)
    plt.imshow(color)

    plt.subplot(1,3,3)
    plt.title('Imagen predicha ', color = 'Red', fontsize = 20)
    plt.imshow(predicted)
   
    plt.show()

mse_ncL, rmse_ncL, psnr_ncL, fsim_ncL, uqi_ncL, ssim_ncL, uiq_ncL, vif_ncL = [],[],[],[],[],[],[],[]
for i in range(0,17):
    predicted = np.clip(autoencoder.predict(color_img[i].reshape(1,SIZE, SIZE,3)),0.0,1.0).reshape(SIZE, SIZE,3)
    plot_images(color_img[i],predicted)

# %% [markdown]
# ## Predicciones del modelo concatenando las capas

# %%
def sorted_alphanumeric(data):  
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)',key)]
    return sorted(data,key = alphanum_key)
# defining the size of the image
SIZE = 160
color_img = []
path = '/content/drive/MyDrive/Proyecto-IA2/BucaramangaImagenes/Resized/160'
files = os.listdir(path)
files = sorted_alphanumeric(files)
for i in tqdm(files):    
    if i == '3000.jpg':
        break
    else:    
        img = cv2.imread(path + '/'+i,1)

        #resizing image
        img = cv2.resize(img, (SIZE, SIZE))
        img = img.astype('float32') / 255.0
        color_img.append(img_to_array(img))
# Out:
# 100%|██████████| 17/17 [00:00<00:00, 146.81it/s]

# %%
from keras.models import Model, load_model
autoencoder = load_model('/content/drive/MyDrive/Proyecto-IA2/Modelos/modelo-AE-concatL.h5')

# %%
def plot_images(color,predicted):
    plt.figure(figsize=(15,15))
    plt.subplot(1,3,1)
    plt.title('Imagen a color', color = 'green', fontsize = 20)
    plt.imshow(color)

    plt.subplot(1,3,3)
    plt.title('Imagen predicha ', color = 'Red', fontsize = 20)
    plt.imshow(predicted)
   
    plt.show()

mse_ncL, rmse_ncL, psnr_ncL, fsim_ncL, uqi_ncL, ssim_ncL, uiq_ncL, vif_ncL = [],[],[],[],[],[],[],[]
for i in range(0,17):
    predicted = np.clip(autoencoder.predict(color_img[i].reshape(1,SIZE, SIZE,3)),0.0,1.0).reshape(SIZE, SIZE,3)
    plot_images(color_img[i],predicted)

# %% [markdown]
# ## Predicciones del modelo concatenando y aumentando las capas

# %%
def sorted_alphanumeric(data):  
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)',key)]
    return sorted(data,key = alphanum_key)
# defining the size of the image
SIZE = 160
color_img = []
path = '/content/drive/MyDrive/Proyecto-IA2/BucaramangaImagenes/Resized/160'
files = os.listdir(path)
files = sorted_alphanumeric(files)
for i in tqdm(files):    
    if i == '3000.jpg':
        break
    else:    
        img = cv2.imread(path + '/'+i,1)

        #resizing image
        img = cv2.resize(img, (SIZE, SIZE))
        img = img.astype('float32') / 255.0
        color_img.append(img_to_array(img))
# Out:
# 100%|██████████| 17/17 [00:00<00:00, 149.90it/s]

# %%
from keras.models import Model, load_model
autoencoder = load_model('/content/drive/MyDrive/Proyecto-IA2/Modelos/modelo-AE-concatM.h5')

# %%
def plot_images(color,predicted):
    plt.figure(figsize=(15,15))
    plt.subplot(1,3,1)
    plt.title('Imagen a color', color = 'green', fontsize = 20)
    plt.imshow(color)

    plt.subplot(1,3,3)
    plt.title('Imagen predicha ', color = 'Red', fontsize = 20)
    plt.imshow(predicted)
   
    plt.show()

mse_ncL, rmse_ncL, psnr_ncL, fsim_ncL, uqi_ncL, ssim_ncL, uiq_ncL, vif_ncL = [],[],[],[],[],[],[],[]
for i in range(0,17):
    predicted = np.clip(autoencoder.predict(color_img[i].reshape(1,SIZE, SIZE,3)),0.0,1.0).reshape(SIZE, SIZE,3)
    plot_images(color_img[i],predicted)
